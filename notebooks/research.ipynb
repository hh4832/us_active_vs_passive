# %% [markdown]
# # US Active vs Passive Research
# Run the audited pipeline from `scripts/run_analysis.py`. This notebook is intentionally thin so production logic remains tested in `src/`.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
print(PROJECT_ROOT)
